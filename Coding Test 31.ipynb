# %%
N = int(input())
ori =list(map(int,input().split()))   # 기존 점수 입력 후 리스트 변환
new = []                              # 새로운 점수 넣을 빈 리스트 생성
for i in ori:
  new.append((i/max(ori))*100)        # 기존 리스트 중 최고 점수로 나누고 곱하기 100 점수 생성
print(sum(new)/N)                     # 새로운 점수 평균
# Out:
# 3
# 40 80 60
# 75.0
