# %%
N = []                    # 빈 리스트 생성
for i in range(9):
  N.append(int(input()))  # for문과 append() 활용해서 빈 리스트에 자연수 추가
print(max(N))
print(N.index(max(N))+1)  # 0부터 시작이기 때문에 +1
# Out:
# 3
# 29
# 38
# 12
# 57
# 74
# 40
# 85
# 61
# 85
# 8
