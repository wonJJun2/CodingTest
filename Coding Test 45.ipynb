# %%
croatia_str = ['c=', 'c-', 'dz=', 'd-', 'lj', 'nj', 's=', 'z=']
word = input()

for i in croatia_str :
    word = word.replace(i, '*')  # 입력 문자에서 croatia_str 문자를  '*'로 대체
print(len(word))
# Out:
# ljes=njak
# 6
