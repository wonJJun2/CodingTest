# %%
a,b = input().split()
print(int(a)+int(b))
# Out:
# 1 2
# 3

# %%
a,b = input().split()
print(int(a)-int(b))

# %%
a,b = input().split()
print(int(a)*int(b))

# %%
a,b = input().split()
print(int(a)/int(b))

# %%
print("|\_/|")
print("|q p|   /}")
print('( 0 )"""\\')  
print('|"^"`    |')
print("||_/=\\\__|")
