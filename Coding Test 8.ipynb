# %%
a,b = map(int,input().split())

if a < b:
  print('<')
elif a > b:
  print('>')
else:
  print('==')
# Out:
# 1 2
# <

# %%
# 오류
a,b = input().split()

if a < b:
  print('<')
elif a > b:
  print('>')
else:
  print('==')
# Out:
# 1 3
# <
