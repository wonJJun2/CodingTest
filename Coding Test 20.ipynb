# %%
T = int(input())

for i in range(T):
  A,B = map(int, input().split())
  print('Case #%d:' %(i+1), A,'+',B,'=' ,A+B)
# Out:
# 5
# 1 1
# Case #1: 1 + 1 = 2
# 2 3
# Case #2: 2 + 3 = 5
# 3 4
# Case #3: 3 + 4 = 7
# 9 8
# Case #4: 9 + 8 = 17
# 5 2
# Case #5: 5 + 2 = 7
