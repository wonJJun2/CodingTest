# %%
sugar = int(input())
bag = 0
while sugar >= 0 :
    if sugar % 5 == 0 :      # 설탕이 5의 배수이면
        bag += (sugar // 5)  # 몫이 봉지가 된다.
        print(bag)
        break
    sugar -= 3  
    bag += 1                  
else :
    print(-1)
# Out:
# 18
# 4
