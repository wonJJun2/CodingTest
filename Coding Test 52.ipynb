# %%
T = int(input())
for i in range(T):
  floor = int(input())
  num = int(input())
  people = [i for i in range(1, num+1)]
  for j in range(floor):
    for k in range(1,num):
      people[k] += people[k-1]
  print(people[-1])
# Out:
# 2
# 1
# 3
# [1, 3, 3]
# [1, 3, 6]
# 6
# 2
# 3
# [1, 3, 3]
# [1, 3, 6]
# [1, 4, 6]
# [1, 4, 10]
# 10
