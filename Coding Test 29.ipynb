# %%
A = int(input())
B = int(input())
C = int(input())

sum = list(str(A*B*C))        # str 해서 각각의 숫자로 나누기 위함

for i in range(10):
  print(sum.count(str(i)))    # 각각 자리수 숫자의 카운트
# Out:
# 150
# 266
# 427
# 3
# 1
# 0
# 2
# 0
# 0
# 0
# 2
# 0
# 0
