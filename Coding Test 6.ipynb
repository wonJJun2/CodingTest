# %%
a,b,c = input().split()
print((int(a)+int(b))%int(c))
print((int(a)%int(c))+(int(b)%int(c)))
print((int(a)*int(b))%int(c))
print((int(a)%int(c))*(int(b)%int(c)))
# Out:
# 5 8 4
# 1
# 1
# 0
# 0
