# %%
n = int(input())

num = 1             # 벌집 시작점 및 시작 개수
cnt = 1             
while n > num :
    num += 6 * cnt  # 벌집 테두리가 6의 배수, 방 최대 숫자
    cnt += 1        # 반복문을 반복하는 횟수, 최소 거리
print(cnt)
# Out:
# 13
# 3
