# %%
N = []                  
for i in range(10):
  N.append(int(input())%42) # 42로 나눈 나머지 숫자들을 리스트에 추가

print(len(set(N)))          # set을 사용하여 중복 허용하지 않은 숫자 카운트
# Out:
# 42
# 84
# 252
# 420
# 840
# 126
# 42
# 84
# 420
# 126
# 1
