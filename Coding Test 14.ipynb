# %%
t = int(input())                      # 테스트의 수

for t in range(t):                    # range()를 통해 테스트의 수만큼 반복
  a,b = map(int, input().split())     # 두 정수 쪼개기
  print(a+b)                          # a+b 출력
# Out:
# 5
# 1 1
# 2
# 2 3
# 5
# 3 4
# 7
# 9 8
# 17
# 5 2
# 7
